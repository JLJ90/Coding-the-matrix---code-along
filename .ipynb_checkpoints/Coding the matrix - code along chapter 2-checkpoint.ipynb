# %% [markdown]
# ### The feild - not the agricultural kind
#
#     A collection of values with addition and multiplication.
#
# #### Complex numbers
#
# i <sup>2</sup> = -1
#
# For any positive number *n*, the solution to i <sup>2</sup> = -n is $\sqrt{n}$ times i.
#
# e.g 9i<sup>2</sup> = -9
#
# (3i)<sup>2</sup> = -9
#
# THe product of a real number and i is an *imaginary number*
#
# What about the equation (x-1)<sup>2</sup> = -9 ?
#
# This can be solved by setting x - 1 = 3i --> x = 1 + 3i
#
# The sum of  a *real* number and a *complex* number

# %% [markdown]
# #### Complex number in Python
#
# j replaces i as 'i' is used for current in electrical engineering
#
# So, 3i is writeen as 3j
#
# i is written as 1j, so as not to confuse with the variable 'j'

# %%
j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3eedd8854d1e> in <module>
# ----> 1 j
#
# NameError: name 'j' is not defined

# %%
1j 


# Python alllows you to add real and imaginary numbers


1+3j
# Out:
# (1+3j)

# %% [markdown]
# All the operators work with imaginary numbers
#
# You cab obtain the imaginary and real parts of a complex number using dot notation
#
# e.g. x.real =

# %%
x = 1+ 3j

print(f'real {x.real}, imaginary {x.imag}')


type(1+2j) # what is the type of this number?
# Out:
# real 1.0, imaginary 3.0
# complex

# %% [markdown]
# #### Abstracting over feilds
#
# Many concepts in linear algebra, theorems and procedures (functions) work for real and complex numbers alike.
#
# $\mathbb{R}$, the feild of real numbers
#
# $\mathbb{C}$, the feild of complex numbers
#
# GF(2) a feild that consists of 0 and 1
#
# Just as referring to the name of a class to refer to a set of instances of that class e.g. pandas.(instance) one uses the name of the feild, e.g $\mathbb{R}$ or GF(2) to refer to the set of values.
#
#
#  #### Playing with $\mathbb{C}$
#
#  Becuase a complex number consists of one part real to one part imaginary it is traditional to think of them as a point (coordinate) in the *complex plane*
#
# Below is the plotting function supplied by codingthematrix.com
#
# and the set S is from the book

# %%
from plotting import plot

# %%
S = {2+2j, 3+2j, 1.75+1j, 2+1j, 2.25+1j, 2.5+1j, 2.75+1j, 3+1j, 3.25+1j}


plot(S,4)

'''
I am guessing this was written when notebooks were not as popular as this opens the plot in a new browser
I would have to mdify the source code to display it in the notebook
'''
# Out:
# '\nI am guessing this was written when notebooks were not as popular as this opens the plot in a new browser\nI would have to mdify the source code to display it in the notebook\n'

# %% [markdown]
# The *absolute value* of a complex number ${z}$ , written $\lvert$ ${z}$ $\rvert$ in python use , abs(z) is the distance from the origin to the corresponding point in the complex plane.
#
# By the Pythagorean Theorem, $\lvert$ ${z}$ $\rvert$ = (${z.real}$)<sup>2</sup> + (${z.imag}$)<sup>2</sup>
#
# z.real is along the x axis and z.imag is the y

# %%
abs(3+4j)
# Out:
# 5.0

# %%
abs(1+1j)
# Out:
# 1.4142135623730951

# %% [markdown]
# The *conjugate* (changing the sign in between the terms e.g. + to -) of a complex number ${z}$ is written $\bar{z}$ and is defined as ${z}$.real - ${z}$.imag

# %%
(3+4j).conjugate()
# Out:
# (3-4j)

# %%
(3+4).conjugate() #only works for complex numbers
# Out:
# 7

# %% [markdown]
# Given that i<sup>2</sup> = -1, we can get a formula for $\lvert$ ${z}$ $\rvert$ <sup>2</sup> in terms of ${z}$ and $\bar{z}$
#
# $\lvert$ ${z}$ $\rvert$ <sup>2</sup> = ${z}$ . $\bar{z}$
#
#
# in words: the absolute value of a complex number squared is equal to

# %% [markdown]
# ### Adding complex numbers
#
#
# f(${z}$)= 1 + 2i + ${z}$ --- so a function that adds 1 + 2i to every complex number ${z}$
#
# it increases the 'real' coordiante by 1 and increases the each imaginary coordiante by 2.
#
# Refering to the previous plot, this would move the image to the top right, this is called a **translation**
#
# #### A translation has the form
#
# f(${z}$) = ${z}$<sub>0</sub> + ${z}$
#
# ** translations can take a picture anywhere in a complex plain.

# %% [markdown]
# Task 1.4.3: Create a new plot using a comprehension to provide a set of points derived from  S by adding 1+2i to each:
#
# Klein, Philip. Coding the Matrix: Linear Algebra through Computer Science Applications (p. 79). Newtonian Press. Kindle Edition.

# %%
plot({1+2j+z for z in S},4) # THe right hand most point is cut off of the rendering for some reason

# %% [markdown]
# Quiz 1.4.4: The “left eye” of the set S of complex numbers is located at 2+2i. For what  value of z0 does the translation f(z) = z0 + z move the left eye to the origin?
#
# Klein, Philip. Coding the Matrix: Linear Algebra through Computer Science Applications (p. 79). Newtonian Press. Kindle Edition.

# %% [markdown]
# I don't really understand this question  - or the answer given. The origin is presumably (0,0) or the original position? So for what complex number moves the 'left eye' to the origin?
#
# The answer seems to be the inverse of the coordiantes in the question (-2-2i +z) which I think makes sense, but it's hard to imagine in my head.
#
# Then what about the next one...
#
# Problem 1.4.5: Show that, for any two distinct points z1 and z2,
# • there is a translation that maps z1 to z2,
# • there is a translation that maps z2 to z1, and
# • there is no translation that both maps z1 to z2 and z2 to z1.
#
# Klein, Philip. Coding the Matrix: Linear Algebra through Computer Science Applications (p. 79). Newtonian Press. Kindle Edition.
#
# Presumably 1 and 2 are just the invers of each other. And therefore, you can't have one that simultaneoulsy does both?

# %% [markdown]
# ### Composing translations, adding arrows
#
# Let f<sub>1</sub>(${z}$) = z<sub>1</sub> + ${z}$ and f<sub>2</sub>(${z}$) = z<sub>2</sub> + ${z}$  their composition is also a translation
#
# (f<sub>1</sub> $\omicron$ f<sub>2</sub> )(${z}$)
#
#  = f<sub>2</sub>(f<sub>1</sub>(${z}$))
#
#  = f<sub>2</sub>(${z1}$ + ${z}$)
#
#  = ${z2}$ + ${z1}$ + ${z}$
#
#
#
# and is defined by z $\mapsto$ (z2 +z1) + z
#
#
# In essence the composition of two arrows gives the third arrow (adding vectors)
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Multiplying complex numbers by a positive real number
#
# With reference to the previous plot if you halved all of the values g(z) = 0.5z
#
# This halves the real and imaginary coordinate of each complex number. With the picture all the points get moved closer to the origin and closer to each other.
#
# this operation is called *scaling*

# %%
plot({z*0.5 for z in S},4)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([i.real for i in S],[i.imag for i in S])
plt.ylim(-5,5)
plt.xlim(-5,5)
# Out:
# (-5, 5)

# %% [markdown]
# ### Multiplying complex numbers by a negative number: rotation by 180 degrees
#
# here is the result of multiplying them by -1

# %%
plt.scatter([i.real * -1 for i in S],[i.imag * -1 for i in S])
plt.ylim(-5,5)
plt.xlim(-5,5)
# Out:
# (-5, 5)

# %% [markdown]
# The inverse image and in this case a rotation by 180 degrees
#
# Multiplying by i: rotation by 90 degrees
#
# (x,y) must be moved to (-y, x) THe complex number located at (x,y) is x + iy. Now we can use the fact that i<sup>2</sup> = -1
#
# h(z) = i . z
#
# multiplying x + iy by i yeilds
#
# ix + i<sup>2</sup>y which is ix -y

# %%
plt.scatter([(i.imag * -1) * 0.5 for i in S],[i.real * 0.5 for i in S])
plt.ylim(-5,5)
plt.xlim(-5,5)
# Out:
# (-5, 5)

# %%
plot({z*1j*0.5 for z in S},4)

# %% [markdown]
# Task 1.4.10: We have provided a module image with a procedure file2image(filename)  that reads in an image stored in a file in the .png format. Import this procedure and invoke it,  providing as argument the name of a file containing an image in this format, assigning the returned  value to variable data. An example grayscale image, img01.png, is available for download.  The value of data is a list of lists, and data[y][x] is the intensity of pixel (x,y). Pixel  (0,0) is at the bottom-left of the image, and pixel (width-1, height-1) is at the top-right.  The intensity of a pixel is a number between 0 (black) and 255 (white).  Use a comprehension to assign to a list pts the set of complex numbers x + yi such that the  image intensity of pixel (x, y) is less than 120, and plot the list pts.
#
# Klein, Philip. Coding the Matrix: Linear Algebra through Computer Science Applications (p. 83). Newtonian Press. Kindle Edition.

# %%
from image import file2image

# %%
image = file2image('img01.png')

# %%
len(image) # number of pixels
# Out:
# 189

# %%
image[0][0] # r,g,b
# Out:
# (183, 183, 183)

# %%
plt.imshow(image)

# %% [markdown]
# I work with images and python a lot and I have almost no idea what this question is asking. First of all I don't think this image is truly greyscale it is simply a list of rgb pixels. The colour of the pixels just happens to be grey.

# %% [markdown]
# So after looking around on the internet I found this https://codingthematrix.com/Errata1.pdf where the author admits its an error, we first need to convert it to an actual greyscale image

# %%
from image import color2gray
image  = color2gray(image)

# %%
image[0][0] # now it's greyscale
# Out:
# 183

# %%
rows = len(image) 
cols =len(image[0]) #essentially the length of a row

# %%
rows
# Out:
# 189

# %% [markdown]
# image is a list of lists, within each list is the 'row'. So we can filter each pixel by for i in image, for j in row etc

# %% [markdown]
# I think the filter needs to come after the transformation?

# %%
pts=[x+(y*-1j) for x in range(cols) for y in range(rows) if image[y][x]<120]
plot(pts,190) # make sure you change the scale from the previous plots, or you will not see the result.

# %% [markdown]
# Task 1.4.11 Write a procedure to center the points of S at the origin

# %% [markdown]
# From earlier: The absolute value of a complex number 𝑧 , written | 𝑧 | in python use , abs(z) is the distance from the origin to the corresponding point in the complex plane.
#
# S = {2+2j, 3+2j, 1.75+1j, 2+1j, 2.25+1j, 2.5+1j, 2.75+1j, 3+1j, 3.25+1j}

# %%
def centering(z):

# %%
plot([s-(2.5+1.5j) for s in S],4) # this puts the image in the center (0,0) I have no idea how to answer this question
                                  # and suprisingly, I can't find anyone on the internet that does. Let's move on, maybe we will learn later

# %% [markdown]
# ### The unit circle in the complex plane: argument and angle
#
# Any rotatation can be represented by complex multiplication. It is conveniant to use *radians* instead of degrees to measure the angle of rotation. Radians... that takes me back a decade or so.
#
# ##### The argument of a complex number on the unit circle
#
# The unit circle radius is one
#
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
#
# It also mentions that it is centered at the origin of the complex plane and the middle is (0,0) so my assumption above was correct. I still am not sure how to trnaslate the numbers we have without trial and error, still more thinking to do.

# %% [markdown]
# #### The argument of a complex number on the unit circle
#
# Consider the unit circle - the circle of radius one, centered at the origin of a **complex** plane.
#
# The distance you have to travel around the circle from one point to another is called the *argument* of z.
#
#
# Since the circumeference of the circle is 2 $\pi$, the point halfway around the circle has an argument of $\pi$, and the point one-eigth of the way around has an argument of $\pi$/4
#
# #### The angle formed by two comlex numbers on the unit circle
#
# The angle formed by the line segements from the origin to two points z1 and z2 is the distance long the circle going anticlockwise
#
#
# The argument of z is the angle formed by z with 1 + 0i (don't understand this remark)

# %% [markdown]
# ### 1.4.7 Euler's formula
#
# for any real number $\theta$,   e<sup> i.$\theta$ </sup> is the point z on the unit circle with the argument $\theta$
#
# e = 2.7182818...

# %% [markdown]
# Example 1.4.16: The point −1+0i has argument π. Plugging π into Euler’s formula yields  the surprising equation eiπ +1=0.
#
# Klein, Philip. Coding the Matrix: Linear Algebra through Computer Science Applications (p. 86). Newtonian Press. Kindle Edition.

# %%
from math import e,pi 

(e**(1j*pi)) + 1 # basically zero
# Out:
# 1.2246467991473532e-16j

# %% [markdown]
# Task 1.4.17: From the module math, import the definitions e and pi. Let n be the integer  20. Let w be the complex number e2πi/n. Write a comprehension yielding the list consisting of  w0, w1, w2,...,wn−1. Plot these complex numbers.
#
# Klein, Philip. Coding the Matrix: Linear Algebra through Computer Science Applications (p. 87). Newtonian Press. Kindle Edition.

# %%
plot([(e**((2*pi*1j)/20))**n for n in range(0,20)],4)

# %% [markdown]
# #### Polar representation for complex numbers
#
# Euler's formula allows for representation of complex numbers that lie on the unit circle. Complex number z, Let **L** be the line segement in the complex plane from the origin to z, and let z<sup>$\prime$</sup>. let *r* be the length of the line to segement z
#
#
# ![image.png](attachment:image.png)
#
#
# I could not find an image the same as in teh book so please refer to page 87. Essentially, Z is beyond the circle and z prime is the distance from the edge of the circle to the point z. r is the total length
#
#
# let *r* be the length of the line segment to z<sup>$\prime$</sup>. Viewing z<sup>$\prime$</sup> as the result of scaling down z, we have
#
# z<sup>$\prime$</sup> = (1 / r)  * z
#
# let $\theta$ be the argument of z<sup>$\prime$</sup> (this distance you travel anticlockwise around the circle). Euler's formula tell's us that z<sup>$\prime$</sup> = e<sup>$\theta$.i</sup>.
#
# We obtain, z = re<sup>$\theta$.i</sup>
#
#
# I don't really understand the scaling down part, which means I don't understand the rest of this.

# %% [markdown]
# #### The first law of Exponentitation
#
#  - When powers multiply, thier exponents add
#      e<sup>u</sup> * e<sup>v</sup> = e<sup>u + v</sup>
#
#
# This can be used to understand how to rotate a complex number
#
#
# #### Rotation by radians
#
# let *rad* be the number of radians. The rotation of z by *rad* should have the same absolute value as z, but it's argument should be *rad* more than that of z, i.e it should be re<sup>($\theta$ + *rad*)i<sup/>
#
#
# The function that rotates by *rad* is smply f(z) = ze<sup>*rad* . i<sup/>
#
# At this point, I don't understand the connection between the higher concept and the maths. I know what is happening but I do not understand it well enough to implement it.
#
# Task 1.4.18 - rotate each element by pi/4

# %%
S = {2+2j, 3+2j, 1.75+1j, 2+1j, 2.25+1j, 2.5+1j, 2.75+1j, 3+1j, 3.25+1j}
import math
# so pi/4 is our radians?

plot([z*(math.e**((math.pi/4)*1j)) for z in S],4)

# %% [markdown]
# So, I got through this by plugging numbers into the formula, and seeing the result I can see that the image has been rotated, i.e the answer is correct. This does not feel right, and is how I have got by in the past.
#
# I understand what we are trying to do and the result, but not the mathw behind it... Someone with a stronger will would not move on until this is understood on a fundamental level. A weaker willed person would trick themselves into thinking they understand it.
#
# ### Playing with GF(2)
#
# Is short for *Galois Field 2*. Founded the field of abstract algebra, then died in a deul at age 20.
#
# The field GF(2) has two elements, 0 and 1.
#
# - Addition is modulo 2, it is equivalent to exclusive or, 1+1 = 0.
# - Subtraction is identical, THe negative of 1 is 1, and the negative of 0 is 0
# - Multiplication in GF(2) is just like ordinary multiplication, this is also true of division.

# %%
import GF2

# %%
GF2.one * GF2.one
# Out:
# one

# %% [markdown]
# ## Review questions
#
# 1. Name three fields
#     - Complex
#     - Galois
#     - Real
#
#
# 2. What is the conjugate of a complex number? What does it have to do with the absolute  value of a complex number?
#     Change the sign of the imaginary number. The absolute value is the difference between the origin (0,0) and the imaginary number.
#
# 3. How does complex-number addition work?
#     Same as normal
#
# 4. How does complex-number multiplication work?
#     Multiply both parts by the real number
#
# 5. How can translation be defined in terms of complex numbers?
#     the composition of two arrows gives the third arrow (adding vectors)
#
# 6. How can scaling be defined in terms of complex numbers?
#     Don't know how to write this
#
# 7. How can rotation by 180 degrees be defined in terms of complex numbers?
#     multiply by -1
#
# 8. How can rotation by 90 degrees be defined in terms of complex numbers?
#     multiply by i

# %% [markdown]
# Now on to the Problems, as with the previous sections I will only answer those that I don't instinctively know hwo to answer. I would say my programming is better than my maths.

# %% [markdown]
# Problem 1.7.11 - Use the first rule of Exponentiation (when multiplying the exponents add)
#
# a = e <sup>3i<sup/>
# b = e <sup>(11/12)i<sup/>

# %% [markdown]
# Problem 1.7.12

# %%
L = [1+2j, 2+2j,  -1 +1j]
a = 1-1j
b = 3+2j

def transform(a,b,L):
    return [(a*z) + b for z in L]

transform(a,b,L)
# Out:
# [(6+3j), (7+2j), (3+4j)]

# %% [markdown]
# a - add one unit to the real and imaginary parts, so they move one point further from the origin?; multiply the imginary part by i (-1) to rotate 90 degrees. I didn't understand why this works before and I still don't but, hey That is true for most things, yet I am. then scale by two, simply multiply both parts by 2?
#
# b - I am not sure about this at all, but to scale you multiply both parts by the same? so scaling them independantly doesn't work. We didn't mention rotating by 45 degrees in the book explicitly by rotate by pi/4.

# %%
b.imag * -1
# Out:
# -2.0

# %% [markdown]
# Ididn't really look at the GF2 stuff as I was eager to get this chapter done. I will use the module to answer a couple of questions

# %%
GF2.one+GF2.one+GF2.one+GF2.zero
# Out:
# one

# %%
GF2.one*GF2.one+GF2.zero*GF2.one+GF2.zero*GF2.zero+GF2.one*GF2.one #becuase 1+1 is zero
# Out:
# 0
